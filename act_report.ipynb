# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# # WeRateDogs Twitter Archive - Act Report

# %% [markdown]
# The project seeks to put in practice all what has been learnt in the Data Wrangling section of this Udacity Nanodegree program. The main goal is to wrangle the WeRateDogs twitter data to draw insights and create visualizations from the data. WeRateDogs is a twitter account that rates people's dogs with humourous comment about the dog.
#
# I was also able to draw some insights and create visualizations from the wrangled data.

# %% [markdown]
# After wrangling the data, I went on to draw some insights from the data.
#
# 1.The three most popular dog Names are Lucy, Charlie and olive
#
# 2.The most retweeted tweet is the tweet with id of 744234799360020481
#
# 3.There is a positive correlation between Retweets and Favourites

# %% [markdown]
# ### Insight 1:

# %% [markdown]
# The three most popular dog Names are Lucy, Charlie and olive

# %% [markdown]
# ### Insight 2:

# %% [markdown]
# The most retweeted tweet is the tweet with id of 744234799360020481. This tweet was made on the 18th of June 2016 and it was liked 131075 times and retweeted 79515 times.

# %% [markdown]
# ### Insight 3:

# %% [markdown]
# There is a positive correlation between Retweets and Favourites

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The scatter plot above depicts that there is a positive correlation between Retweets and Favorites but since there is no statistical operation performed here, we can't be certain.

# %% [markdown]
# ### Question: The most popular dog breed?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# From the pie chart above, it can be deduced that the most popular dog breed is the golden retriever which accounts for 31% of the tweets with a total number of 158 tweets of total being about the dog breed. The golden retriever has about 50 tweets more than the labrador_retreiver which comes in second place with a total number of 108 tweets.

# %% [markdown]
# ### Limitation:
#
#  The missing records in the image predictions file and JSON file may affect the insights drawn and the visulaizations created.
